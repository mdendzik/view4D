# %%
from view4D import View4D,loadh5

# %%
dataset_key = 'MoTe2_IR300mW_short'
file_path = '/data/processed/202406/2H-MoTe2/'+dataset_key+'.h5'
xr_data=loadh5(dataset_key,file_path)

# %%
test=View4D(xr_data)
# Out:
# RFBOutputContext()
# GraphicsLayoutWidget(css_height='1000px', css_width='1000px')

# %%
test.win.snapshot()
# Out:
# <div class='snapshot-dba0b5d8224547cabf4e0f7660b37b5f' style='position:relative;'><img src='data:image/png;base64,...' style='width:926px;height:1098px;' /><div style='position: absolute; top:0; left:0; padding:1px 3px; background: #777; color:#fff; font-size: 90%; font-family:sans-serif; '>snapshot</div></div>
